# %% [markdown]
# <a href="https://colab.research.google.com/github/Manimegalai-33/Data-Cleaning-Visualization-Project/blob/main/Data_Cleaning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Name': ['Asha', 'Priya', 'Kaviya', 'Divya', 'Meena', 'Priya', 'Anu'],
    'Age': [18, 19, 18, 20, 19, 19, 18],
    'Marks': [85, 78, None, 91, 78, 78, 67],
    'Attendance': [90, 88, 92, 95, 88, 88, 80]
}

df = pd.DataFrame(data)

df['Marks'] = df['Marks'].fillna(df['Marks'].mean())
df = df.drop_duplicates()

print(df)

plt.bar(df['Name'], df['Marks'])
plt.title('Student Marks')
plt.show()

plt.pie(df['Attendance'], labels=df['Name'], autopct='%1.1f%%')
plt.title('Attendance Distribution')
plt.show()
# Out:
#      Name  Age  Marks  Attendance
# 0    Asha   18   85.0          90
# 1   Priya   19   78.0          88
# 2  Kaviya   18   79.5          92
# 3   Divya   20   91.0          95
# 4   Meena   19   78.0          88
# 6     Anu   18   67.0          80
